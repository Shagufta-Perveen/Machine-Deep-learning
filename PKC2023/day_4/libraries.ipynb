# %% [markdown]
# 1. pandas
# 2. numpy
# 3. matplotlib
# 4. seaborn
# 5. plotly
# 6. scipy
# 7. scikit_learn
# 8. streamlit

# %%
#pip install pandas numpy matplotlib seaborn plotly

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
#plotting
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="r", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# C:\Users\Buzz Tech\AppData\Local\Temp\ipykernel_14476\3322937968.py:8: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>
